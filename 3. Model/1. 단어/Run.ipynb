# %% [markdown]
# ## **Learn an effective Lip Reading model without pains**
# -------------------------------
# ### 0. 구글 드라이브 마운트 및 PyTurboJPEG 설치

# %%
from google.colab import drive
drive.mount('./MyDrive')
# Out:
# Mounted at ./MyDrive

# %%
# %cd /content/MyDrive/MyDrive/LipReading
# Out:
# /content/MyDrive/MyDrive/LipReading

# %%
# !sudo apt-get update
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ Packages [62.9 kB]
# Ign:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:4 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:5 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Ign:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release [697 B]
# Hit:8 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:9 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release.gpg [836 B]
# Hit:11 http://archive.ubuntu.com/ubuntu bionic InRelease
# ...

# %%
# !sudo apt-get install libturbojpeg
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libturbojpeg is already the newest version (1.5.2-0ubuntu5.18.04.4).
# 0 upgraded, 0 newly installed, 0 to remove and 98 not upgraded.

# %%
# !pip install -U git+git://github.com/lilohuang/PyTurboJPEG.git
# Out:
# ...
#   Cloning git://github.com/lilohuang/PyTurboJPEG.git to /tmp/pip-req-build-inhkqubl
#   Running command git clone -q git://github.com/lilohuang/PyTurboJPEG.git /tmp/pip-req-build-inhkqubl
# ...
#   Created wheel for PyTurboJPEG: filename=PyTurboJPEG-1.5.1-py3-none-any.whl size=8837 sha256=b9ae4f30983c70af7b7c51623aac4d0bc492b77ef292fdea295fc3e3d5bc6190
#   Stored in directory: /tmp/pip-ephem-wheel-cache-8199ctd1/wheels/21/50/68/b54f0a11d3a0b572cc428fee1501970d1d3962e4d18e414cb2
# Successfully built PyTurboJPEG
# ...

# %% [markdown]
# ## 1. 전처리 실행

# %%
# !python scripts/prepare_lrw.py
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 12 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# eta:0.05364
# eta:0.01341

# %% [markdown]
# ## 2. 모델 학습 진행

# %%
import torch

if torch.cuda.is_available():
  device_count = torch.cuda.device_count()
  print("device_count: {}".format(device_count))
  for device_num in range(device_count):
    print("device {} capability {}".format(
        	device_num,
          torch.cuda.get_device_capability(device_num)))
    print("device {} name {}".format(
	        device_num, torch.cuda.get_device_name(device_num)))
else:
  print("no cuda device")
# Out:
# device_count: 1
# device 0 capability (3, 7)
# device 0 name Tesla K80

# %%
# !python main_visual.py \
    --gpus='0'  \
    --lr=3e-4 \
    --batch_size=400 \
    --num_workers=8 \
    --max_epoch=120 \
    --test=False \
    --save_prefix='checkpoints/lrw-baseline/' \
    --n_class=500 \
    --dataset='lrw' \
    --border=False \
    --mixup=False \
    --label_smooth=False \
    --se=False
# Out:
# Start Training, Data Length: 34
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# epoch=0,train_iter=0,eta=0.00317,CE V=6.21301,lr=0.003750,best_acc=0.000000
# Start Testing, Data Length: 34
# start testing
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# ...

# %%
# !python main_visual.py \
    --gpus='0'  \
    --lr=0.0 \
    --batch_size=128 \
    --num_workers=8 \
    --max_epoch=120 \
    --test=True \
    --save_prefix='checkpoints/lrw-baseline/' \
    --n_class=2 \
    --dataset='lrw' \
    --border=False \
    --mixup=False \
    --label_smooth=False \
    --se=False \
    --weights='checkpoints/lrw-baseline/_iter_107_epoch_107_v_acc_0.73529_.pt'
# Out:
# load weights
# loaded params/tot params:149/151
# miss matched params: ['v_cls.weight', 'v_cls.bias']
# Start Testing, Data Length: 34
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# start testing
# v_acc=0.50000,eta=0.00042
# acc=0.5
