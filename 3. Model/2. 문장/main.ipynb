# %% [markdown]
# ## **Deep Lip Reading: A comparison of models and an online application**
# -------------------------------
# ### 0. 구글 드라이브 마운트 및 requirments 설치
# - 텐서플로우 구버전이 필요함

# %%
# %cd /content/drive/Shareddrives/MBC 뉴스/210825
# Out:
# /content/drive/Shareddrives/MBC 뉴스/210825

# %%
# !pip uninstall -y tensorflow
# Out:
# Found existing installation: tensorflow 2.6.0
# Uninstalling tensorflow-2.6.0:
#   Successfully uninstalled tensorflow-2.6.0

# %%
# !pip install tensorflow==1.13.1
# Out:
# ...
#      |████████████████████████████████| 92.6 MB 1.4 MB/s
# ...
#      |████████████████████████████████| 50 kB 6.7 MB/s
# ...
#      |████████████████████████████████| 367 kB 43.3 MB/s
# ...
#      |████████████████████████████████| 3.2 MB 41.4 MB/s
# ...
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.6.0
#     Uninstalling tensorflow-estimator-2.6.0:
#       Successfully uninstalled tensorflow-estimator-2.6.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.6.0
#     Uninstalling tensorboard-2.6.0:
#       Successfully uninstalled tensorboard-2.6.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# kapre 0.3.5 requires tensorflow>=2.0.0, but you have tensorflow 1.13.1 which is incompatible.
# ...

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 345.0 MB 3.7 kB/s
# ...
#      |████████████████████████████████| 37.2 MB 30 kB/s
# ...
#      |████████████████████████████████| 26.9 MB 88 kB/s
# ...

# %% [markdown]
# ### 0-1. 최초 실행시 - 모델 다운로드

# %%
# !chmod +x ./download_models.sh

# %%
# !./download_models.sh
# Out:
# --2021-08-25 02:30:02--  http://www.robots.ox.ac.uk/~vgg/research/deep_lip_reading/models/lrs2_lip_model.zip
# Resolving www.robots.ox.ac.uk (www.robots.ox.ac.uk)... 129.67.94.2
# Connecting to www.robots.ox.ac.uk (www.robots.ox.ac.uk)|129.67.94.2|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://www.robots.ox.ac.uk/~vgg/research/deep_lip_reading/models/lrs2_lip_model.zip [following]
# --2021-08-25 02:30:02--  https://www.robots.ox.ac.uk/~vgg/research/deep_lip_reading/models/lrs2_lip_model.zip
# Connecting to www.robots.ox.ac.uk (www.robots.ox.ac.uk)|129.67.94.2|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 190637960 (182M) [application/zip]
# Saving to: ‘lrs2_lip_model.zip’
#
# lrs2_lip_model.zip  100%[===================>] 181.81M  21.4MB/s    in 9.6s
#
# 2021-08-25 02:30:13 (19.0 MB/s) - ‘lrs2_lip_model.zip’ saved [190637960/190637960]
#
# Archive:  lrs2_lip_model.zip
# ...

# %% [markdown]
# ### 1. 모델 실제 적용

# %%
# !python main.py --gpu_id 0 --lip_model_path models/lrs2_lip_model --data_path main/Pitchfork --data_list media/lrs2_test_samples.txt
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
# !python main.py --gpu_id 0 --lip_model_path models/lrs2_lip_model --lm_path models/lrs2_language_model --data_path main/Pitchfork --data_list media/lrs2_test_samples.txt --graph_type infer --test_aug_times 2  --beam_size 35
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %% [markdown]
# ----------------------

# %%
# !python main.py --gpu_id 0 --lip_model_path models/lrs2_lip_model --data_path data/lrk/main --data_list data/lrk/main/lrk_samples2.txt
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...
